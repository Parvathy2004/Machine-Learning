# %% [markdown]
# ## Import necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load the dataset

# %%
df=pd.read_csv('50_Startups.csv')
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %% [markdown]
# ## Define the columns in dataset

# %%
df.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit'], dtype='object')

# %% [markdown]
# ## Check info of the columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# ## View first 5 rows

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %% [markdown]
# ## View last 10 rows

# %%
df.tail(10)
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 40   28754.33       118546.05        172795.67  California  78239.91
# 41   27892.92        84710.77        164470.71     Florida  77798.83
# 42   23640.93        96189.63        148001.11  California  71498.49
# 43   15505.73       127382.30         35534.17    New York  69758.98
# 44   22177.74       154806.14         28334.72  California  65200.33
# 45    1000.23       124153.04          1903.93    New York  64926.08
# 46    1315.46       115816.21        297114.46     Florida  49490.75
# 47       0.00       135426.92             0.00  California  42559.73
# 48     542.05        51743.15             0.00    New York  35673.41
# 49       0.00       116983.80         45173.06  California  14681.40

# %% [markdown]
# ## Check for any null values present in the dataset

# %%
df.isna().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %% [markdown]
# ## Plot a histogram

# %%
sns.histplot(df['Profit'])
plt.show()

# %% [markdown]
# ## Plot a countplot of the categorical data

# %%
sns.countplot(x=df['State'])
plt.show()

# %% [markdown]
# ## How many unique categories are there in the categorical column 'State'?

# %%
df['State'].nunique()
# Out:
# 3

# %% [markdown]
# ## How many companies have a 'Profit' greater than $100,000?

# %%
df[df['Profit']>100000]
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
df['Profit'][df['Profit']>100000].count()
# Out:
# 30

# %% [markdown]
# ## What is the average 'Profit' for companies in each 'State'?

# %%
df.groupby(['State'])['Profit'].mean()
# Out:
# State
# California    103905.175294
# Florida       118774.024375
# New York      113756.446471
# Name: Profit, dtype: float64

# %% [markdown]
# ## Encode the categorical variables using one-hot encoding

# %%
newdf = pd.get_dummies(df)
newdf.head()
# Out:
#    R&D Spend  Administration  Marketing Spend     Profit  State_California  \
# 0  165349.20       136897.80        471784.10  192261.83                 0
# 1  162597.70       151377.59        443898.53  191792.06                 1
# 2  153441.51       101145.55        407934.54  191050.39                 0
# 3  144372.41       118671.85        383199.62  182901.99                 0
# 4  142107.34        91391.77        366168.42  166187.94                 0
#
#    State_Florida  State_New York
# 0              0               1
# 1              0               0
# 2              1               0
# 3              0               1
# 4              1               0

# %% [markdown]
# ## Perform feature scaling on numerical features.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_x = scaler.fit_transform(X)
scaled_x = pd.DataFrame(scaled_x, columns=X.columns)
scaled_x.head()
# Out:
#    R&D Spend  Administration  Marketing Spend
# 0   2.016411        0.560753         2.153943
# 1   1.955860        1.082807         1.923600
# 2   1.754364       -0.728257         1.626528
# 3   1.554784       -0.096365         1.422210
# 4   1.504937       -1.079919         1.281528

# %% [markdown]
# ## Assign X and Y variables respectively

# %%
X = newdf.drop(columns=['Profit','State_California','State_Florida','State_New York'])
Y = newdf['Profit']
X.head()
# Out:
#    R&D Spend  Administration  Marketing Spend
# 0  165349.20       136897.80        471784.10
# 1  162597.70       151377.59        443898.53
# 2  153441.51       101145.55        407934.54
# 3  144372.41       118671.85        383199.62
# 4  142107.34        91391.77        366168.42

# %% [markdown]
# ## Split the data into training and testing

# %%
X = pd.concat([scaled_x, newdf[['State_California','State_Florida','State_New York']]], axis=1)
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.3,random_state=100)

# %% [markdown]
# ## MODEL BUILDING

# %% [markdown]
# ## Create a multiple linear regression model

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Check training score of model

# %%
model.score(X_train,Y_train)
# Out:
# 0.9664558318047836

# %% [markdown]
# ## Predict the model

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# ## Evaluate the testing data using mean squared error

# %%
from sklearn.metrics import mean_squared_error
print ('Mean Squared Error is: ', mean_squared_error(Y_test, y_pred))
# Out:
# Mean Squared Error is:  169303616.1286992
